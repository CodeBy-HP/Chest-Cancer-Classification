# %%
print("hello")
# Out:
# hello

# %%
url = "https://drive.google.com/file/d/1wfCS_2E7aY2xFywLLwsuEo-7VHbycGBL/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1wfCS_2E7aY2xFywLLwsuEo-7VHbycGBL'

# %%
import gdown
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1wfCS_2E7aY2xFywLLwsuEo-7VHbycGBL
# To: c:\Users\asus\Desktop\Deep Learning project\Chest-Cancer-Classification\research\Chest-CT-Scan-data.zip
# 100%|██████████| 42.0M/42.0M [00:47<00:00, 884kB/s]
# 'Chest-CT-Scan-data.zip'
